# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahmatul-Rovi/Machine-Learning-Practice/blob/main/Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Student Grade Calculator
# সব Python basics একসাথে use করা হয়েছে!
def get_grade(marks):
  if marks>=80:
    return "A+"
  elif marks>=70:
    return "A"
  elif marks>=60:
    return "B"
  else:
    return "Fail"

# Student data
students = [
    {"name": "Rahim", "marks": [85, 90, 78, 92, 88]},
    {"name": "Karim", "marks": [70, 65, 80, 75, 72]},
    {"name": "Jamal", "marks": [55, 60, 58, 62, 50]},
]
