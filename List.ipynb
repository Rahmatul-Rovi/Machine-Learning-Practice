# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahmatul-Rovi/Machine-Learning-Practice/blob/main/List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruits = ['Mango', 'Banana', 'Apple', 'Orange', ]
numbers = [10,20,30,40,50]

print(fruits[0])
print(fruits[-1])
print(fruits[1:3])

fruits.append('Guava')
print(fruits)

fruits.remove('Banana')
print(fruits)

print(len(fruits))
print(max(numbers))
print(min(numbers))
print(sum(numbers))
# Out:
# Mango
# Orange
# ['Banana', 'Apple']
# ['Mango', 'Banana', 'Apple', 'Orange', 'Guava']
# ['Mango', 'Apple', 'Orange', 'Guava']
# 4
# 50
# 10
# 150
