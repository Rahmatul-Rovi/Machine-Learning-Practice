# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahmatul-Rovi/Machine-Learning-Practice/blob/main/If_Else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
marks = 75

if marks >= 80:
    print("A grade")
elif marks >= 70:
    print("B grade")
elif marks >= 60:
    print("C grade")
else:
    print("Fail")

    age=18
    if(age>=18):
      print('You are eligible for vote')
    else:
        print(f"After{18-age} years you will eligible for vote.")

        num=-5
        if(num>0):
          print('Positive')
        elif(num<0):
            print('Negative')
        else:
              print('Zero')
# Out:
# B grade

# %%
age=18
if(age>=18):
      print('You are eligible for vote')
else:
        print(f"After{18-age} years you will eligible for vote.")
# Out:
# You are eligible for vote

# %%
num=-5
if(num>0):
          print('Positive')
elif(num<0):
            print('Negative')
else:
              print('Zero')
# Out:
# Negative
