# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahmatul-Rovi/Machine-Learning-Practice/blob/main/Data_Show_%26_Analyze.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data Basic Info
print(df.shape)
print(df.columns)
print(df.info())
print(df.describe())

# Specific Column Show
print(df["Name"])
print(df["Marks"])

dhaka_students = df[df["City"] == "Dhaka"]
print(dhaka_students)

good_students = df[df["Marks"] > 80]
print(good_students)

# Average marks
print(f"Average marks: {df['Marks'].mean():.2f}")
print(f"Highest marks: {df['Marks'].max()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2904/3566800826.py in <cell line: 0>()
#       1 # Data Basic Info
# ----> 2 print(df.shape)
#       3 print(df.columns)
#       4 print(df.info())
#       5 print(df.describe())
#
# NameError: name 'df' is not defined
