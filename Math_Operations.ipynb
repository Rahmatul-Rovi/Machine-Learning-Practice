# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahmatul-Rovi/Machine-Learning-Practice/blob/main/Math_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=20
b=6

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)

#BMI Calculation
weight = 70
height = 1.75
bmi = weight / (height ** 2)
print(f'Your BMI: {bmi:.2f}')
# Out:
# 26
# 14
# 120
# 3.3333333333333335
# 3
# 2
# 64000000
# Your BMI: 22.86
