# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahmatul-Rovi/Machine-Learning-Practice/blob/main/Print_and_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello Brother!')
print('I am learning Python')

name = "Rovi"
age = 23
height = 5.8
is_student = True

print(name)
print(age)
print(height)
print(is_student)

print(f"My Name {name}, Age {age}, Height {height}")
# Out:
# Hello Brother!
# I am learning Python
# Rovi
# 23
# 5.8
# True
# My Name Rovi, Age 23, Height 5.8

# %%
x=10
print(type(x))

y=3.14
print(type(y))

z = "Hello"
print(type(z))

b = True
print(type(b))

num_str = "100"
num_int = int(num_str)
print(num_int + 50)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# 150
