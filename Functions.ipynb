# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahmatul-Rovi/Machine-Learning-Practice/blob/main/Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Simple Function
def greet(name):
  print(f"Hello , {name}")

  greet("Rovi")
  greet("brother")

# Return Function
def add(a,b):
 result = a + b
 return result

 answer = add(10,20)
 print(answer)

# Real example functions
def calculate_bmi(weight , height):
  bmi = weight / (height **2 )
  return round(bmi,2)

def bmi_category(bmi):
  if bmi < 18.5:
    return "Underweight"
  elif bmi < 25:
      return "Normal"
  elif bmi < 30:
        return "OverWeight"
  else:
          return "Obese"

my_bmi = calculate_bmi(78 , 1.72)
category = bmi_category(my_bmi)
print(f"BMI: {my_bmi} - {category}")
# Out:
# BMI: 26.37 - OverWeight
