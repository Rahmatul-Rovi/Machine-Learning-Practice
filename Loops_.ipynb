# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahmatul-Rovi/Machine-Learning-Practice/blob/main/Loops_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#For Loop
for i in range (5):
  print(f"Number: {i}")

#List Loop
fruits = ["Apple", "Banana", "Mango"]
for fruit in fruits:
  print(f"Fruits: {fruit}")

#While Loop
count = 0
while count < 5:
  print(f"Count: {count}")
  count +=1

#Real Example
marks = [80,70, 90, 75, 85]
total = 0
for mark in marks:
  total += mark
  average = total /len(marks)
  print(f"Average Marks: {average}")

#Nested Loop
for i in range(1,4):
   for j in range(1,4):
       print(f"i X j: {i}* {j}")
# Out:
# Number: 0
# Number: 1
# Number: 2
# Number: 3
# Number: 4
# Fruits: Apple
# Fruits: Banana
# Fruits: Mango
# Count: 0
# Count: 1
# Count: 2
# Count: 3
# Count: 4
# Average Marks: 16.0
# Average Marks: 30.0
# Average Marks: 48.0
# Average Marks: 63.0
# Average Marks: 80.0
# i X j: 1* 1
# i X j: 1* 2
# i X j: 1* 3
# i X j: 2* 1
# i X j: 2* 2
# i X j: 2* 3
# i X j: 3* 1
# i X j: 3* 2
# i X j: 3* 3
