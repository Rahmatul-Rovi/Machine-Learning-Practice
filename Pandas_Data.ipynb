# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahmatul-Rovi/Machine-Learning-Practice/blob/main/Pandas_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# DataFrame
data = {
    "Name": ["Rahim", "Karim", "Jamal", "Raju", "Sohel"],
    "Age": [20, 22, 21, 23, 20],
    "Marks": [85, 92, 78, 88, 76],
    "City": ["Dhaka", "Chittagong", "Dhaka", "Sylhet", "Dhaka"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age  Marks        City
# 0  Rahim   20     85       Dhaka
# 1  Karim   22     92  Chittagong
# 2  Jamal   21     78       Dhaka
# 3   Raju   23     88      Sylhet
# 4  Sohel   20     76       Dhaka
