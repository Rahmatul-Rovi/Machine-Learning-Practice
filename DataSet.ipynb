# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahmatul-Rovi/Machine-Learning-Practice/blob/main/DataSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
sujaykapadnis_fast_food_calories_data_path = kagglehub.dataset_download('sujaykapadnis/fast-food-calories-data')

print('Data source import complete.')

# %%
import pandas as pd
dataset = pd.read_csv('/kaggle/input/datasets/sujaykapadnis/fast-food-calories-data/fastfood_calories.csv')

# %%
df = pd.DataFrame(dataset)
print(df)
# Out:
#      Unnamed: 0 restaurant                                       item  \
# 0             1  Mcdonalds           Artisan Grilled Chicken Sandwich
# 1             2  Mcdonalds             Single Bacon Smokehouse Burger
# 2             3  Mcdonalds             Double Bacon Smokehouse Burger
# 3             4  Mcdonalds  Grilled Bacon Smokehouse Chicken Sandwich
# 4             5  Mcdonalds   Crispy Bacon Smokehouse Chicken Sandwich
# ..          ...        ...                                        ...
# 510         511  Taco Bell             Spicy Triple Double Crunchwrap
# 511         512  Taco Bell                Express Taco Salad w/ Chips
# 512         513  Taco Bell                     Fiesta Taco Salad-Beef
# 513         514  Taco Bell                  Fiesta Taco Salad-Chicken
# 514         515  Taco Bell                    Fiesta Taco Salad-Steak
#
#      calories  cal_fat  total_fat  sat_fat  trans_fat  cholesterol  sodium  \
# ...

# %%
print(data.head(10))
print(data.tail(10))
# Out:
#    Unnamed: 0 restaurant                                       item  calories  \
# 0           1  Mcdonalds           Artisan Grilled Chicken Sandwich       380
# 1           2  Mcdonalds             Single Bacon Smokehouse Burger       840
# 2           3  Mcdonalds             Double Bacon Smokehouse Burger      1130
# 3           4  Mcdonalds  Grilled Bacon Smokehouse Chicken Sandwich       750
# 4           5  Mcdonalds   Crispy Bacon Smokehouse Chicken Sandwich       920
# 5           6  Mcdonalds                                    Big Mac       540
# 6           7  Mcdonalds                               Cheeseburger       300
# 7           8  Mcdonalds                   Classic Chicken Sandwich       510
# 8           9  Mcdonalds                        Double Cheeseburger       430
# 9          10  Mcdonalds        Double Quarter Pounder® with Cheese       770
#
#    cal_fat  total_fat  sat_fat  trans_fat  cholesterol  sodium  total_carb  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515 entries, 0 to 514
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   515 non-null    int64
#  1   restaurant   515 non-null    object
#  2   item         515 non-null    object
#  3   calories     515 non-null    int64
#  4   cal_fat      515 non-null    int64
#  5   total_fat    515 non-null    int64
#  6   sat_fat      515 non-null    float64
#  7   trans_fat    515 non-null    float64
#  8   cholesterol  515 non-null    int64
#  9   sodium       515 non-null    int64
#  10  total_carb   515 non-null    int64
#  11  fiber        503 non-null    float64
#  12  sugar        515 non-null    int64
#  13  protein      514 non-null    float64
#  14  vit_a        301 non-null    float64
#  15  vit_c        305 non-null    float64
#  16  calcium      305 non-null    float64
#  17  salad        515 non-null    object
# ...

# %%
# Count number of missing value


print(data.isna())
# Out:
#      Unnamed: 0  restaurant   item  calories  cal_fat  total_fat  sat_fat  \
# 0         False       False  False     False    False      False    False
# 1         False       False  False     False    False      False    False
# 2         False       False  False     False    False      False    False
# 3         False       False  False     False    False      False    False
# 4         False       False  False     False    False      False    False
# ..          ...         ...    ...       ...      ...        ...      ...
# 510       False       False  False     False    False      False    False
# 511       False       False  False     False    False      False    False
# 512       False       False  False     False    False      False    False
# 513       False       False  False     False    False      False    False
# 514       False       False  False     False    False      False    False
#
#      trans_fat  cholesterol  sodium  total_carb  fiber  sugar  protein  vit_a  \
# ...

# %%
# Handle The Missing Values
print(data.isna().sum())
# Out:
# Unnamed: 0       0
# restaurant       0
# item             0
# calories         0
# cal_fat          0
# total_fat        0
# sat_fat          0
# trans_fat        0
# cholesterol      0
# sodium           0
# total_carb       0
# fiber           12
# sugar            0
# protein          1
# vit_a          214
# vit_c          210
# calcium        210
# salad            0
# dtype: int64

# %%
mean = data[['fiber', 'protein', 'vit_a', 'vit_c', 'calcium']].mean()
print(mean)
ss = data.fillna(mean)
print(ss)
# Out:
# fiber       4.137177
# protein    27.891051
# vit_a      18.857143
# vit_c      20.170492
# calcium    24.852459
# dtype: float64
#      Unnamed: 0 restaurant                                       item  \
# 0             1  Mcdonalds           Artisan Grilled Chicken Sandwich
# 1             2  Mcdonalds             Single Bacon Smokehouse Burger
# 2             3  Mcdonalds             Double Bacon Smokehouse Burger
# 3             4  Mcdonalds  Grilled Bacon Smokehouse Chicken Sandwich
# 4             5  Mcdonalds   Crispy Bacon Smokehouse Chicken Sandwich
# ..          ...        ...                                        ...
# 510         511  Taco Bell             Spicy Triple Double Crunchwrap
# 511         512  Taco Bell                Express Taco Salad w/ Chips
# 512         513  Taco Bell                     Fiesta Taco Salad-Beef
# 513         514  Taco Bell                  Fiesta Taco Salad-Chicken
# 514         515  Taco Bell                    Fiesta Taco Salad-Steak
# ...
