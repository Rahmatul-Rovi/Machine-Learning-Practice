# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahmatul-Rovi/Machine-Learning-Practice/blob/main/Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student={
    "name": "Rovi",
    "age": 23,
    "marks": 85,
    "city": "Dhaka"
}

print(student["name"])
print(student["city"])
print(student["marks"])

student["marks"] = 90
print(student)

student["subject"]= "CSE"
print(student)

print(student.keys())
print(student.values())

students=[
    {"name":"Rovi", "Marks": 90},
    {"name":"Bijoy", "Marks": 80},
    {"name":"Alif", "Marks": 85},
]

print(students[1])

print(students[2]["name"])

print(students)
# Out:
# Rovi
# Dhaka
# 85
# {'name': 'Rovi', 'age': 23, 'marks': 90, 'city': 'Dhaka'}
# {'name': 'Rovi', 'age': 23, 'marks': 90, 'city': 'Dhaka', 'subject': 'CSE'}
# dict_keys(['name', 'age', 'marks', 'city', 'subject'])
# dict_values(['Rovi', 23, 90, 'Dhaka', 'CSE'])
# {'name': 'Bijoy', 'Marks': 80}
# Alif
# [{'name': 'Rovi', 'Marks': 90}, {'name': 'Bijoy', 'Marks': 80}, {'name': 'Alif', 'Marks': 85}]
