# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahmatul-Rovi/Machine-Learning-Practice/blob/main/String_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Data Science"

print(len(name))
print(name.upper())
print(name.lower())
print(name[0])
print(name[0:4])
print(name.replace("Data", "Machine Learning"))

# String Merged
first = "Machine"
last = "Learning"
full = first + " " + last
print(full)

# Check
sentence = "Python is Awesome"
print('Python' in sentence)
print('Java' in sentence )
# Out:
# 12
# DATA SCIENCE
# data science
# D
# Data
# Machine Learning Science
# Machine Learning
# True
# False
